# %% [markdown]
# # Experiment 1
# Load the Students Performance dataset and display the first few records. Identify numerical and categorical columns. Compute measures of central tendency (mean, median, mode) and measures of dispersion (minimum, maximum, variance, and standard deviation).

# %%
import pandas as pd

df = pd.read_csv("StudentsPerformance.csv")

print("First 5 records:")
print(df.head())

# identify columns
numerical_cols = df.select_dtypes(include=["number"]).columns
categorical_cols = df.select_dtypes(include=["object"]).columns

print("\nNumerical Columns:")
print(numerical_cols)

print("\nCategorical Columns:")
print(categorical_cols)

# select score columns
scores = df[["math score", "reading score", "writing score"]]

print("\nMean:")
print(scores.mean())

print("\nMedian:")
print(scores.median())

print("\nMode:")
print(scores.mode().iloc[0])

print("\nMinimum:")
print(scores.min())

print("\nMaximum:")
print(scores.max())

print("\nSum:")
print(scores.sum())

print("\nVariance:")
print(scores.var())

print("\nStandard Deviation:")
print(scores.std())
# Out:
# First 5 records:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
# Numerical Columns:
# Index(['math score', 'reading score', 'writing score'], dtype='str')
#
# Categorical Columns:
# ...

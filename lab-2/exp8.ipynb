# %% [markdown]
# # Experiment 8
# Create a scatter plot between two numerical features and interpret their relationship.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data.csv")

plt.scatter(df["Age"], df["Salary"])

plt.title("Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")

plt.show()

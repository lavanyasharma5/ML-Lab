# %% [markdown]
# # Experiment 4
# Display column data types and convert selected columns to appropriate data types using `astype()`. Verify the changes.

# %%
import pandas as pd

df = pd.read_csv("data.csv")

print("Data types before conversion:")
print(df.dtypes)

# Fill missing values first
df["Age"] = df["Age"].fillna(df["Age"].mean())

# Now convert datatype
df["Age"] = df["Age"].astype(int)
df["Salary"] = df["Salary"].astype(float)

print("\nData types after conversion:")
print(df.dtypes)
# Out:
# Data types before conversion:
# ID              int64
# Name              str
# Age           float64
# Gender            str
# Department        str
# Salary        float64
# Year            int64
# Sales           int64
# dtype: object
#
# Data types after conversion:
# ID              int64
# Name              str
# Age             int64
# Gender            str
# Department        str
# Salary        float64
# Year            int64
# Sales           int64
# dtype: object
